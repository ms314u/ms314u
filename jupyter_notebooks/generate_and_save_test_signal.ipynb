# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
n = 10000
sig = np.hstack((np.random.randn(n), np.random.randn(n) + 1))

# %%
plt.plot(sig)

# %%
np.savetxt("C:/1maslov/tmp/tstsig.txt", sig)

# %%
sig2 = np.loadtxt("C:/1maslov/tmp/tstsig.txt")

# %%
plt.plot(sig2)

# %%
[e for e in range(1)]
# Out:
# [0]
