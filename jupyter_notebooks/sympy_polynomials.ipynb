# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
#
import sympy
from sympy import symbols, integrate, diff, poly
from sympy.functions import exp
from sympy import init_printing
init_printing(use_unicode=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# http://docs.sympy.org/latest/modules/polys/index.html

# %%
x, p1,p2,p3 = symbols("x, p1, p2,p3")
a = poly((p1 + p2*x + p3*x**2)**2)
c = a.all_coeffs()
a
# Out:
# ---------------------------------------------------------------------------
# PolynomialError                           Traceback (most recent call last)
# <ipython-input-51-f29ff9ba6c09> in <module>()
#       1 x, p1,p2,p3 = symbols("x, p1, p2,p3")
#       2 a = poly((p1 + p2*x + p3*x**2)**2)
# ----> 3 c = a.all_coeffs()
#       4 a
#
# C:\1maslov\Continuum\Anaconda3\lib\site-packages\sympy\polys\polytools.py in all_coeffs(f)
#     811
#     812         """
# --> 813         return [f.rep.dom.to_sympy(c) for c in f.rep.all_coeffs()]
#     814
#     815     def all_monoms(f):
#
# C:\1maslov\Continuum\Anaconda3\lib\site-packages\sympy\polys\polyclasses.py in all_coeffs(f)
#     306                 return [ c for c in f.rep ]
#     307         else:
# --> 308             raise PolynomialError('multivariate polynomials not supported')
#     309
#     310     def all_monoms(f):
#
# PolynomialError: multivariate polynomials not supported

# %%
def f(probs, p):
    s = sympy.Poly.from_list(probs, gens=x)
    s = s**p
    c = list(s.all_coeffs())
    return c
#a = f([0.1, 0.5, 0.4], 9)

# %%
res = []
ps = [0.1, 0.5, 0.4]
for power in range(1, 100):
    res.append(f(ps, power))

# %%
for v in res:
    plt.plot(v)
